# %% [markdown]
# <a href="https://colab.research.google.com/github/AtishayJain27/MACHINELEARNING-PCS662/blob/main/Final_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.linear_model import LinearRegression
x = np.array([5,15,25,45,35,45,55]).reshape(-1, 1)
y = np.array([5,20,14,32,22,38,10])
model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)
plt.scatter(x, y, color="red", label="actual data")
plt.plot(x, y_pred, color="green", label="Regression line")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Regression ")
plt.show()

# %%
x=[1,2]
y=[2,3]
ab=y[0]**2-x[0]**2
ord=y[1]**2-x[1]**2
sum=ab+ord
print(sum**0.5)
# Out:
# 2.8284271247461903
